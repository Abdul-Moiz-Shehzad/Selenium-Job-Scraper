# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.edge.service import Service
from selenium.webdriver.edge.options import Options
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException, ElementNotInteractableException
import pandas as pd
import time

def get_jobs(keyword, num_jobs, verbose):
    '''Gathers jobs as a dataframe, scraped from Glassdoor'''
    
    # Initializing the webdriver
    options = Options()
    
    # Uncomment the line below if you'd like to scrape without a new Chrome window every time.
    # options.add_argument('headless')
    
    # Change the path to where chromedriver is in your home folder.
    chrome_path = "msedgedriver.exe"
    service = Service(chrome_path)
    driver = webdriver.Edge(service=service, options=options)
    driver.set_window_size(1120, 1000)
    char = str(len(keyword))
    url = 'https://www.glassdoor.com/Job/' + keyword + '-jobs-SRCH_KO0,' + char + '.htm'
    driver.get(url)
    jobs = []
    time.sleep(5)
    processed = set()
    while len(jobs) < num_jobs:
        # Going through each job in this page
        try:
            job_cards = driver.find_elements(By.CLASS_NAME, 'JobCard_jobCardContainer___hKKI')
            print("Found job cards:", len(job_cards))
        except:
            continue
            pass
        
        print("Progress: {}".format("" + str(len(jobs)) + "/" + str(num_jobs)))
        if len(jobs) >= num_jobs:
            break
        
        for job_card in job_cards:
            if len(jobs)>=num_jobs:
                return pd.DataFrame(jobs)
            try:
                driver.find_element(By.XPATH, "/html/body/div[11]/div[2]/div[2]/div[1]/div[1]/button").click()  # clicking to the X.
                print("clicked the cross")
            except NoSuchElementException:
                pass
            job_url = job_card.find_element(By.CLASS_NAME, 'JobCard_jobTitle___7I6y').get_attribute('href')
            if job_url not in processed:
                try:
                    job_card.click()
                    time.sleep(2)
                    collected_successfully = False
                    while not collected_successfully:
                        try:
                            company_name = job_card.find_element(By.CLASS_NAME, 'EmployerProfile_compactEmployerName__LE242').text
                            location = job_card.find_element(By.CLASS_NAME, 'JobCard_location__rCz3x').text
                            job_title = job_card.find_element(By.CLASS_NAME, 'JobCard_jobTitle___7I6y').text
                            job_description = job_card.find_element(By.CLASS_NAME, 'JobCard_jobDescriptionSnippet__yWW8q').text
                            collected_successfully = True
                            processed.add(job_url)
                        except NoSuchElementException:
                            time.sleep(5)
                    try:
                        salary_estimate = job_card.find_element(By.CLASS_NAME, 'JobCard_salaryEstimate__arV5J').text
                    except NoSuchElementException:
                        salary_estimate = -1  # You need to set a "not found value. It's important."
                
                    try:
                        rating = job_card.find_element(By.CLASS_NAME, 'EmployerProfile_ratingContainer__ul0Ef').text
                    except NoSuchElementException:
                        rating = -1  # You need to set a "not found value. It's important."
                    
                    # Printing for debugging
                    if verbose:
                        print("Job Title: {}".format(job_title))
                        print("Salary Estimate: {}".format(salary_estimate))
                        print("Job Description: {}".format(job_description[:500]))
                        print("Rating: {}".format(rating))
                        print("Company Name: {}".format(company_name))
                        print("Location: {}".format(location))
                    
                    # Going to the Company tab...
                    time.sleep(3)
                    j=1
                    try:
                        size = driver.find_element(By.XPATH,'(//div[@class="JobDetails_overviewItemValue__xn8EF"])['+str(j)+']').text
                        j+=1
                    except NoSuchElementException:
                        size = -1
                    try:
                        founded = driver.find_element(By.XPATH,'(//div[@class="JobDetails_overviewItemValue__xn8EF"])['+str(j)+']').text
                        j+=1
                    except NoSuchElementException:
                        founded = -1
                    try:
                        type_of_ownership = driver.find_element(By.XPATH,'(//div[@class="JobDetails_overviewItemValue__xn8EF"])['+str(j)+']').text
                        j+=1
                    except NoSuchElementException:
                        type_of_ownership = -1
                    try:
                        industry = driver.find_element(By.XPATH,'(//div[@class="JobDetails_overviewItemValue__xn8EF"])['+str(j)+']').text
                        j+=1
                    except NoSuchElementException:
                        industry = -1
                    try:
                        sector = driver.find_element(By.XPATH,'(//div[@class="JobDetails_overviewItemValue__xn8EF"])['+str(j)+']').text
                        j+=1
                    except NoSuchElementException:
                        sector = -1
                    try:
                        revenue = driver.find_element(By.XPATH,'(//div[@class="JobDetails_overviewItemValue__xn8EF"])['+str(j)+']').text
                        j+=1
                    except NoSuchElementException:
                        revenue = -1
                    
                    if verbose:
                        print("Size: {}".format(size))
                        print("Founded: {}".format(founded))
                        print("Type of Ownership: {}".format(type_of_ownership))
                        print("Industry: {}".format(industry))
                        print("Sector: {}".format(sector))
                        print("Revenue: {}".format(revenue))
                        print("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@")
                    
                    jobs.append({
                        "Job Title": job_title,
                        "Salary Estimate": salary_estimate,
                        "Job Description": job_description,
                        "Rating": rating,
                        "Company Name": company_name,
                        "Location": location,
                        "Size": size,
                        "Founded": founded,
                        "Type of ownership": type_of_ownership,
                        "Industry": industry,
                        "Sector": sector,
                        "Revenue": revenue,
                        "URL": job_url,
                    })
                except ElementClickInterceptedException:
                    print("Error clicking on job card")
                    continue
                except ElementNotInteractableException:
                    print("Job card not interactable")
                    continue
        try:
            driver.find_element(By.XPATH, '(//button[@class="button_Button__MlD2g button-base_Button__knLaX"])[2]').click()
            time.sleep(3)
        except:
            print("Scraping terminated before reaching target number of jobs. Needed {}, got {}.".format(num_jobs, len(jobs)))
            break
    
    driver.quit()
    return pd.DataFrame(jobs)  # This line converts the dictionary object into a pandas DataFrame.

# Example usage:
df = get_jobs(input("Enter the keyword you want to search"), int(input("Enter the number of jobs you want")), bool(input("Do you want the output to be displayed simultaneously")))
# Out:
# Found job cards: 30
# Progress: 0/35
# Job Title: Data Analyst
# Salary Estimate: $75K - $198K (Employer est.)
# Job Description: If you have a foundation in online platform trust and safety issues, skills in data analysis and and an empathetic approach to mentoring and collaborating with……
# Skills: Data analysis skills, SQL, Machine learning, GitHub, Data science
# Rating: 3.8
# Company Name: GitHub, Inc.
# Location: Remote
# Size: 1001 to 5000 Employees
# Founded: 2008
# Type of Ownership: Subsidiary or Business Segment
# Industry: Internet & Web Services
# Sector: Information Technology
# Revenue: Unknown / Non-Applicable
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Data Analytics
# Salary Estimate: $38.00 - $45.00 Per Hour (Employer est.)
# Job Description: Minimum three years experience in data science applications. Very strong preference for SAS programming experience.…
# Rating: 3.9
# Company Name: J & S Consulting
# Location: Tucker, GA
# Size: 51 to 200 Employees
# Founded: --
# Type of Ownership: Company - Private
# Industry: Information Technology Support Services
# Sector: Information Technology
# Revenue: $5 to $25 million (USD)
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# clicked the cross
# Job Title: Data Science Analyst
# Salary Estimate: $55K - $60K (Employer est.)
# Job Description: Bachelor's degree in Computer Science, Statistics, Mathematics, or a related field; Master's. Familiarity with big data technologies and tools for processing……
# Skills: Data mining, SAS, Big data, R, Data analysis skills
# Rating: 4.0
# Company Name: TRESUME
# Location: Washington, DC
# Size: 1 to 50 Employees
# Founded: --
# Type of Ownership: Company - Public
# Industry: --
# Sector: --
# Revenue: Unknown / Non-Applicable
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Research Data Analyst
# Salary Estimate: $98K - $108K (Employer est.)
# Job Description: Select, adapt, and apply appropriate quantitative and qualitative research design and statistical tools and techniques to all areas of study, which include but……
# Skills: Microsoft Word, CRM software, Google Docs, Microsoft Excel, Microsoft Access
# Rating: 3.8
# Company Name: Calbright College
# Location: California
# Size: 51 to 200 Employees
# Founded: 2019
# Type of Ownership: Company - Public
# Industry: Colleges & Universities
# Sector: Education
# Revenue: Unknown / Non-Applicable
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Data Scientist
# Salary Estimate: $66.82 - $80.54 Per Hour (Employer est.)
# Job Description: End-to-end data and model pipeline deployment and automation technologies. Propose and implement innovative solutions to streamline processes, increase……
# Skills: Spark, Machine learning, Software development, Python
# Rating: 4.4
# Company Name: Boston Technology
# Location: Malvern, PA
# Size: 51 to 200 Employees
# Founded: 2004
# Type of Ownership: Company - Private
# Industry: Information Technology Support Services
# Sector: Information Technology
# Revenue: $5 to $25 million (USD)
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Data Scientist
# Salary Estimate: $120K - $130K (Employer est.)
# Job Description: Data science: 1 year (Preferred). Expertise in programming using Python. Working knowledge of deploying ML models as REST APIs.…
# Skills: TensorFlow, Azure, Kubernetes, Computer vision, Data analysis skills
# Rating: 4.0
# Company Name: element technologies
# Location: Remote
# Size: 51 to 200 Employees
# Founded: 2000
# Type of Ownership: Company - Private
# Industry: Information Technology Support Services
# Sector: Information Technology
# Revenue: Unknown / Non-Applicable
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Data Engineer
# Salary Estimate: $112K - $140K (Employer est.)
# Job Description: A minimum of a BS degree in computer science, software engineering, or related scientific discipline is desired. $25/wk in Doordash credit.…
# Skills: CI/CD, Data modeling, Big data, Spark, Test-driven development
# Rating: 2.3
# Company Name: Verana Health
# Location: Remote
# Size: 51 to 200 Employees
# Founded: 2018
# Type of Ownership: Company - Private
# Industry: Enterprise Software & Network Solutions
# Sector: Information Technology
# Revenue: Unknown / Non-Applicable
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Data Engineer
# Salary Estimate: $105K - $160K (Employer est.)
# Job Description: Communicates technical concepts to non-technical audiences both in written and verbal form. The Data Engineer is responsible for developing data pipelines and……
# Skills: CI/CD, Data modeling, Azure, Oracle, XML
# Rating: 3.9
# Company Name: Costco Wholesale
# Location: Dallas, TX
# Size: 10000+ Employees
# Founded: 1976
# Type of Ownership: Company - Public
# Industry: General Merchandise & Superstores
# Sector: Retail & Wholesale
# Revenue: Unknown / Non-Applicable
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Data Science Analyst
# Salary Estimate: $55K - $65K (Employer est.)
# Job Description: Bachelor's degree in Computer Science, Statistics, Mathematics, or a related field; Master's or Ph.D. preferred.…
# Skills: Statistical software, Data mining, SAS, Big data, R
# Rating: 4.0
# Company Name: TRESUME
# Location: Ashburn, VA
# Size: 1 to 50 Employees
# Founded: --
# Type of Ownership: Company - Public
# Industry: --
# Sector: --
# Revenue: Unknown / Non-Applicable
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Data Engineer
# Salary Estimate: $63K - $105K (Glassdoor est.)
# Job Description: Experience with a wide range of data warehousing tools, including multiple ETL, query and reporting tools, visualization techniques, data mining tools and……
# Skills: Google Suite, Data mining, Relational databases, Procurement, NoSQL
# Rating: 4.4
# Company Name: DotCMS
# Location: Miami, FL
# Size: 1 to 50 Employees
# Founded: --
# Type of Ownership: Company - Private
# Industry: Research & Development
# Sector: Management & Consulting
# Revenue: Unknown / Non-Applicable
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Data Scientist (Hourly Remote)
# Salary Estimate: $45.00 - $80.00 Per Hour (Employer est.)
# Job Description: They will be encouraged to propose innovative ideas for new tools and functionality as well as develop improvements for existing solutions.…
# Skills: Statistical analysis, AWS, Analysis skills, Machine learning, Python
# Rating: 4.1
# Company Name: ARES Corporation
# Location: United States
# Size: 501 to 1000 Employees
# Founded: 1992
# Type of Ownership: Company - Private
# Industry: Aerospace & Defense
# Sector: Aerospace & Defense
# Revenue: $100 to $500 million (USD)
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Data Scientist
# Salary Estimate: $80.00 - $100.00 Per Hour (Employer est.)
# Job Description: A Bachelor's degree in Data Science, Statistics, Computer Science, Business Analytics, or a closely related field is required. Data science: 4 years (Required).…
# Skills: Azure, R, Google Cloud Platform, SQL, Statistical analysis
# Rating: 4.5
# Company Name: Signify Technology
# Location: Florida
# Size: 51 to 200 Employees
# Founded: 2016
# Type of Ownership: Company - Private
# Industry: HR Consulting
# Sector: Human Resources & Staffing
# Revenue: $5 to $25 million (USD)
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Data Science Co-Op
# Salary Estimate: $84K - $109K (Glassdoor est.)
# Job Description: Work with source control tools like GIT to save and control data. Create and use Java scripts with React for front end GUI. Minimum 3.2 GPA (must be on resume).…
# Skills: Computer science, React, Git, Java, Machine learning
# Rating: 4.1
# Company Name: Hunter Engineering Company
# Location: Bridgeton, MO
# Size: 1001 to 5000 Employees
# Founded: 1946
# Type of Ownership: Company - Private
# Industry: Machinery Manufacturing
# Sector: Manufacturing
# Revenue: $500 million to $1 billion (USD)
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Associate Data Science Analyst
# Salary Estimate: $82K - $107K (Glassdoor est.)
# Job Description: Outstanding communication skills, including the ability to explain technical topics and concepts to a non-technical audience. Up to 4% matching 401(k).…
# Skills: R, Machine learning, Leadership, Communication skills, Python
# Rating: 3.3
# Company Name: OneMain Financial
# Location: Wilmington, DE
# Size: 5001 to 10000 Employees
# Founded: 1912
# Type of Ownership: Company - Public
# Industry: Banking & Lending
# Sector: Financial Services
# Revenue: Unknown / Non-Applicable
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Product Manager, Data Science
# Salary Estimate: -1
# Job Description: A BA/BS degree in a related field and a minimum of 3 years of related experience; or any combination of education and experience that provides an equivalent……
# Skills: Analysis skills, Project management, Machine learning, Organizational skills, Data science
# Rating: 3.7
# Company Name: Revecore
# Location: Remote
# Size: 1001 to 5000 Employees
# Founded: --
# Type of Ownership: Company - Private
# Industry: Business Consulting
# Sector: Management & Consulting
# Revenue: Unknown / Non-Applicable
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: DATA SCIENCE: SAP Next Talent - Rotational Program (2024 Grads)
# Salary Estimate: $101K - $172K (Employer est.)
# Job Description: Knowledge in Python, R, SQL and data science methodologies. Hands-on experience with data structures, complexity analysis, and foundation models or LLMs.…
# Skills: TensorFlow, Management, Data structures, R, ERP systems
# Rating: 4.2
# Company Name: SAP
# Location: Palo Alto, CA
# Size: 10000+ Employees
# Founded: 1972
# Type of Ownership: Company - Public
# Industry: Enterprise Software & Network Solutions
# Sector: Information Technology
# Revenue: $10+ billion (USD)
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Data/Analytics Engineer
# Salary Estimate: $117K - $152K (Employer est.)
# Job Description: Experience: 3+ years of experience in data engineering, analytics, or a related field. Communication: Excellent communication skills with the ability to explain……
# Skills: Power BI, Azure, R, Microsoft SQL Server, Git
# Rating: 3.8
# Company Name: Wilson Language Training
# Location: Remote
# Size: 51 to 200 Employees
# Founded: --
# Type of Ownership: Company - Private
# Industry: Education & Training Services
# Sector: Education
# Revenue: $5 to $25 million (USD)
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Data Analyst
# Salary Estimate: $55K - $60K (Employer est.)
# Job Description: Bachelors/ masters in Data science, data analytics, engineering or any equivalent field. Visualizing data to make it easier to understand.…
# Skills: Statistics, Power BI, Microsoft Excel, CSS, SQL
# Rating: 4.0
# Company Name: TRESUME
# Location: Marietta, GA
# Size: 1 to 50 Employees
# Founded: --
# Type of Ownership: Company - Public
# Industry: --
# Sector: --
# Revenue: Unknown / Non-Applicable
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Data Science
# Salary Estimate: $117K - $229K (Employer est.)
# Job Description: Doctorate in Data Science, Mathematics, Statistics, Econometrics, Economics, Operations Research, Computer Science, or related field AND 3+ years data-science……
# Skills: Statistics, Machine learning, Data science
# Rating: 4.2
# Company Name: Microsoft
# Location: Redmond, WA
# Size: 10000+ Employees
# Founded: 1975
# Type of Ownership: Company - Public
# Industry: Computer Hardware Development
# Sector: Information Technology
# Revenue: $10+ billion (USD)
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Data Analyst
# Salary Estimate: $55.00 Per Hour (Employer est.)
# Job Description: Communicate findings, insights, and recommendations to technical and non-technical stakeholders. 8 years of experience and a Bachelor's in Data Science,……
# Skills: Computer science, Power BI, Data modeling, SAS, Big data
# Rating: 4.7
# Company Name: TAYS INC
# Location: Baltimore, MD
# Size: Unknown
# Founded: --
# Type of Ownership: Company - Private
# Industry: --
# Sector: --
# Revenue: Unknown / Non-Applicable
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Data Scientist
# Salary Estimate: $99K - $119K (Employer est.)
# Job Description: BSc/BA in Computer Science, Engineering or relevant field; graduate degree in Data Science or other quantitative field is preferred.…
# Skills: Statistics, Data mining, Business intelligence, R, Tableau
# Rating: -1
# Company Name: Career Vest
# Location: Remote
# Size: -1
# Founded: -1
# Type of Ownership: -1
# Industry: -1
# Sector: -1
# Revenue: -1
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Data Engineer
# Salary Estimate: $45.00 - $52.00 Per Hour (Employer est.)
# Job Description: Build, improve and maintain data infrastructure documentation and data dictionaries. Support the Data Science team by providing clean, reliable, and timely data……
# Skills: Power BI, Alteryx, Microsoft SQL Server, Google Cloud Platform, Tableau
# Rating: 3.7
# Company Name: INSPYR Solutions
# Location: Remote
# Size: 201 to 500 Employees
# Founded: 2002
# Type of Ownership: Company - Private
# Industry: Information Technology Support Services
# Sector: Information Technology
# Revenue: Unknown / Non-Applicable
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Data Engineer
# Salary Estimate: -1
# Job Description: The ideal candidate will have a strong background in data engineering, data analytics, and data science, with the ability to transform data into actionable……
# Skills: Power BI, Data structures, NoSQL, Tableau, Databases
# Rating: 5.0
# Company Name: WRS Health
# Location: Remote
# Size: Unknown
# Founded: --
# Type of Ownership: Company - Public
# Industry: Software Development
# Sector: Information Technology
# Revenue: Unknown / Non-Applicable
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Data Scientist
# Salary Estimate: $92K - $151K (Glassdoor est.)
# Job Description: Experience with data engineering and data science infrastructure design. Master's degree in a relevant field, or a Bachelor's degree and equivalent practical……
# Skills: Statistics, SQL, Analysis skills, Machine learning, Data science
# Rating: 4.0
# Company Name: RADAR
# Location: San Jose, CA
# Size: 501 to 1000 Employees
# Founded: --
# Type of Ownership: Self-employed
# Industry: Civic & Social Services
# Sector: Nonprofit & NGO
# Revenue: $25 to $100 million (USD)
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Engineer II Data Science
# Salary Estimate: -1
# Job Description: Chat-Bot models to auto-answer searches and typed questions from agents. Two (2) years in any occupation with experience in Information Systems, or related must……
# Skills: TensorFlow, Data mining, R, Machine learning, APIs
# Rating: 3.7
# Company Name: Foundever
# Location: Remote
# Size: 10000+ Employees
# Founded: 1994
# Type of Ownership: Company - Private
# Industry: Telecommunications Services
# Sector: Telecommunications
# Revenue: $1 to $5 billion (USD)
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Data Analyst
# Salary Estimate: $44.79 - $49.19 Per Hour (Employer est.)
# Job Description: Education Level: Bachelor's Degree (Data Science, Mathematics, Computer Science, Statistics, Business or related field). Job Types: Full-time, Contract.…
# Skills: EDI, Big data, Data analysis skills, NoSQL, Analysis skills
# Rating: 3.4
# Company Name: KMM Technologies, Inc.
# Location: Washington, DC
# Size: 1 to 50 Employees
# Founded: --
# Type of Ownership: Company - Private
# Industry: Business Consulting
# Sector: Management & Consulting
# Revenue: $5 to $25 million (USD)
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Data Scientist
# Salary Estimate: -1
# Job Description: Data Analysis: Collect, clean, and analyze data using advanced statistical techniques, machine learning algorithms, and data visualization tools.…
# Skills: TensorFlow, Power BI, Calculus, Spark, R
# Rating: -1
# Company Name: DILS srl
# Location: Remote
# Size: 51 to 200 Employees
# Founded: --
# Type of Ownership: Company - Private
# Industry: --
# Sector: --
# Revenue: Unknown / Non-Applicable
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Data Analyst
# Salary Estimate: $85K - $100K (Employer est.)
# Job Description: Were seeking a talented and experienced Data Analyst that willenable data driven decisions, clinical excellence and commercial success throughout Kooth, by the……
# Skills: Business intelligence, Tableau, SQL, Data analytics, Data visualization
# Rating: 3.9
# Company Name: Kooth USA
# Location: Chicago, IL
# Size: 501 to 1000 Employees
# Founded: 2001
# Type of Ownership: Company - Public
# Industry: Health Care Services & Hospitals
# Sector: Healthcare
# Revenue: $25 to $100 million (USD)
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Data Engineer
# Salary Estimate: $130K - $150K (Employer est.)
# Job Description: The Data Engineer role will be the technical liaison between multiple groups including a data science team, the engineering team, product management, and……
# Skills: Data modeling, Microsoft Excel, Management, Relational databases, Data structures
# Rating: 4.0
# Company Name: Integrated Specialty Coverages, LLC
# Location: Remote
# Size: Unknown
# Founded: --
# Type of Ownership: Company - Private
# Industry: Insurance Carriers
# Sector: Insurance
# Revenue: Unknown / Non-Applicable
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Associate Performance Data Scientist
# Salary Estimate: $66K - $70K (Employer est.)
# Job Description: As needed, assist with developing and validating new algorithms, analysis tools, and predictive models. The associate develops tools to optimize performance……
# Skills: Cloud infrastructure, R, HIPAA, SQL, AWS
# Rating: 2.7
# Company Name: United States Olympic & Paralympic Committee
# Location: Remote
# Size: 501 to 1000 Employees
# Founded: 1894
# Type of Ownership: Nonprofit Organization
# Industry: Sports & Recreation
# Sector: Arts, Entertainment & Recreation
# Revenue: $100 to $500 million (USD)
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Found job cards: 60
# Progress: 30/35
# Job Title: Machine Learning Engineer
# Salary Estimate: -1
# Job Description: Hands-on experience with state-of-the-art computer vision models (object detection, classification, segmentation).…
# Skills: TensorFlow, Azure, Computer vision, Google Cloud Platform, Research
# Rating: 4.1
# Company Name: Leverege
# Location: Remote
# Size: 1 to 50 Employees
# Founded: 2014
# Type of Ownership: Company - Private
# Industry: Enterprise Software & Network Solutions
# Sector: Information Technology
# Revenue: Unknown / Non-Applicable
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Associate Marketing Data Scientist
# Salary Estimate: $80K - $115K (Employer est.)
# Job Description: Education Requirement: *Degree in Computer Science, Physics, Machine Learning, Math, Bioinformatics, Engineering, or equivalent technical field.…
# Skills: Statistics, Computer science, R, NoSQL, Git
# Rating: 4.0
# Company Name: Indeed
# Location: Remote
# Size: 10000+ Employees
# Founded: 2004
# Type of Ownership: Company - Private
# Industry: Internet & Web Services
# Sector: Information Technology
# Revenue: $1 to $5 billion (USD)
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Data Analyst
# Salary Estimate: $64K - $97K (Employer est.)
# Job Description: 2+ years of experience in data analysis or a related field. 5+ years of experience in data analysis or a related field. Competitive salary and benefits package.…
# Skills: Power BI, Microsoft Excel, R, Data analysis skills, Microsoft Office
# Rating: -1
# Company Name: NetGator
# Location: Remote
# Size: -1
# Founded: -1
# Type of Ownership: -1
# Industry: -1
# Sector: -1
# Revenue: -1
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Data Science Analyst
# Salary Estimate: -1
# Job Description: This role is very collaborative, working with a variety data science roles and business functions to design and implement data analysis, tools and reporting……
# Skills: Microsoft Powerpoint, Microsoft Excel, Data mining, Data analysis skills, Microsoft Office
# Rating: 3.8
# Company Name: Home Depot / THD
# Location: United States
# Size: 10000+ Employees
# Founded: 1978
# Type of Ownership: Company - Public
# Industry: Home Furniture & Housewares Stores
# Sector: Retail & Wholesale
# Revenue: $10+ billion (USD)
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# Job Title: Data Scientist
# Salary Estimate: $110K - $125K (Employer est.)
# Job Description: This position will play a critical role in interacting with engineering and clinical teams, healthcare payer executives, managers, and frontline staff users,……
# Skills: TensorFlow, Spark, Laboratory experience, Java, SQL
# Rating: 3.5
# Company Name: Evolent Health
# Location: Remote
# Size: 1001 to 5000 Employees
# Founded: 2011
# Type of Ownership: Company - Public
# Industry: Health Care Services & Hospitals
# Sector: Healthcare
# Revenue: $25 to $100 million (USD)
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

# %%
df
# Out:
#                                             Job Title  \
# 0                                        Data Analyst
# 1                                      Data Analytics
# 2                                Data Science Analyst
# 3                               Research Data Analyst
# 4                                      Data Scientist
# 5                                      Data Scientist
# 6                                       Data Engineer
# 7                                       Data Engineer
# 8                                Data Science Analyst
# 9                                       Data Engineer
# 10                     Data Scientist (Hourly Remote)
# 11                                     Data Scientist
# 12                                 Data Science Co-Op
# 13                     Associate Data Science Analyst
# 14                      Product Manager, Data Science
# 15  DATA SCIENCE: SAP Next Talent - Rotational Pro...
# 16                            Data/Analytics Engineer
# 17                                       Data Analyst
# 18                                       Data Science
# 19                                       Data Analyst
# 20                                     Data Scientist
# 21                                      Data Engineer
# 22                                      Data Engineer
# 23                                     Data Scientist
# 24                           Engineer II Data Science
# 25                                       Data Analyst
# 26                                     Data Scientist
# 27                                       Data Analyst
# 28                                      Data Engineer
# 29               Associate Performance Data Scientist
# 30                          Machine Learning Engineer
# 31                 Associate Marketing Data Scientist
# 32                                       Data Analyst
# 33                               Data Science Analyst
# 34                                     Data Scientist
#
#                               Salary Estimate  \
# 0                $75K - $198K (Employer est.)
# 1    $38.00 - $45.00 Per Hour (Employer est.)
# 2                 $55K - $60K (Employer est.)
# 3                $98K - $108K (Employer est.)
# 4    $66.82 - $80.54 Per Hour (Employer est.)
# 5               $120K - $130K (Employer est.)
# 6               $112K - $140K (Employer est.)
# 7               $105K - $160K (Employer est.)
# 8                 $55K - $65K (Employer est.)
# 9               $63K - $105K (Glassdoor est.)
# 10   $45.00 - $80.00 Per Hour (Employer est.)
# 11  $80.00 - $100.00 Per Hour (Employer est.)
# 12              $84K - $109K (Glassdoor est.)
# 13              $82K - $107K (Glassdoor est.)
# 14                                         -1
# 15              $101K - $172K (Employer est.)
# 16              $117K - $152K (Employer est.)
# 17                $55K - $60K (Employer est.)
# 18              $117K - $229K (Employer est.)
# 19            $55.00 Per Hour (Employer est.)
# 20               $99K - $119K (Employer est.)
# 21   $45.00 - $52.00 Per Hour (Employer est.)
# 22                                         -1
# 23              $92K - $151K (Glassdoor est.)
# 24                                         -1
# 25   $44.79 - $49.19 Per Hour (Employer est.)
# 26                                         -1
# 27               $85K - $100K (Employer est.)
# 28              $130K - $150K (Employer est.)
# 29                $66K - $70K (Employer est.)
# 30                                         -1
# 31               $80K - $115K (Employer est.)
# 32                $64K - $97K (Employer est.)
# 33                                         -1
# 34              $110K - $125K (Employer est.)
#
#                                       Job Description Rating  \
# 0   If you have a foundation in online platform tr...    3.8
# 1   Minimum three years experience in data science...    3.9
# 2   Bachelor's degree in Computer Science, Statist...    4.0
# 3   Select, adapt, and apply appropriate quantitat...    3.8
# 4   End-to-end data and model pipeline deployment ...    4.4
# 5   Data science: 1 year (Preferred). Expertise in...    4.0
# 6   A minimum of a BS degree in computer science, ...    2.3
# 7   Communicates technical concepts to non-technic...    3.9
# 8   Bachelor's degree in Computer Science, Statist...    4.0
# 9   Experience with a wide range of data warehousi...    4.4
# 10  They will be encouraged to propose innovative ...    4.1
# 11  A Bachelor's degree in Data Science, Statistic...    4.5
# 12  Work with source control tools like GIT to sav...    4.1
# 13  Outstanding communication skills, including th...    3.3
# 14  A BA/BS degree in a related field and a minimu...    3.7
# 15  Knowledge in Python, R, SQL and data science m...    4.2
# 16  Experience: 3+ years of experience in data eng...    3.8
# 17  Bachelors/ masters in Data science, data analy...    4.0
# 18  Doctorate in Data Science, Mathematics, Statis...    4.2
# 19  Communicate findings, insights, and recommenda...    4.7
# 20  BSc/BA in Computer Science, Engineering or rel...     -1
# 21  Build, improve and maintain data infrastructur...    3.7
# 22  The ideal candidate will have a strong backgro...    5.0
# 23  Experience with data engineering and data scie...    4.0
# 24  Chat-Bot models to auto-answer searches and ty...    3.7
# 25  Education Level: Bachelor's Degree (Data Scien...    3.4
# 26  Data Analysis: Collect, clean, and analyze dat...     -1
# 27  Were seeking a talented and experienced Data A...    3.9
# 28  The Data Engineer role will be the technical l...    4.0
# 29  As needed, assist with developing and validati...    2.7
# 30  Hands-on experience with state-of-the-art comp...    4.1
# 31  Education Requirement: *Degree in Computer Sci...    4.0
# 32  2+ years of experience in data analysis or a r...     -1
# 33  This role is very collaborative, working with ...    3.8
# 34  This position will play a critical role in int...    3.5
#
#                                     Company Name        Location  \
# 0                                   GitHub, Inc.          Remote
# 1                               J & S Consulting      Tucker, GA
# 2                                        TRESUME  Washington, DC
# 3                              Calbright College      California
# 4                              Boston Technology     Malvern, PA
# 5                           element technologies          Remote
# 6                                  Verana Health          Remote
# 7                               Costco Wholesale      Dallas, TX
# 8                                        TRESUME     Ashburn, VA
# 9                                         DotCMS       Miami, FL
# 10                              ARES Corporation   United States
# 11                            Signify Technology         Florida
# 12                    Hunter Engineering Company   Bridgeton, MO
# 13                             OneMain Financial  Wilmington, DE
# 14                                      Revecore          Remote
# 15                                           SAP   Palo Alto, CA
# 16                      Wilson Language Training          Remote
# 17                                       TRESUME    Marietta, GA
# 18                                     Microsoft     Redmond, WA
# 19                                      TAYS INC   Baltimore, MD
# 20                                   Career Vest          Remote
# 21                              INSPYR Solutions          Remote
# 22                                    WRS Health          Remote
# 23                                         RADAR    San Jose, CA
# 24                                     Foundever          Remote
# 25                        KMM Technologies, Inc.  Washington, DC
# 26                                      DILS srl          Remote
# 27                                     Kooth USA     Chicago, IL
# 28           Integrated Specialty Coverages, LLC          Remote
# 29  United States Olympic & Paralympic Committee          Remote
# 30                                      Leverege          Remote
# 31                                        Indeed          Remote
# 32                                      NetGator          Remote
# 33                              Home Depot / THD   United States
# 34                                Evolent Health          Remote
#
#                        Size Founded               Type of ownership  \
# 0    1001 to 5000 Employees    2008  Subsidiary or Business Segment
# 1       51 to 200 Employees      --               Company - Private
# 2         1 to 50 Employees      --                Company - Public
# 3       51 to 200 Employees    2019                Company - Public
# 4       51 to 200 Employees    2004               Company - Private
# 5       51 to 200 Employees    2000               Company - Private
# 6       51 to 200 Employees    2018               Company - Private
# 7          10000+ Employees    1976                Company - Public
# 8         1 to 50 Employees      --                Company - Public
# 9         1 to 50 Employees      --               Company - Private
# 10    501 to 1000 Employees    1992               Company - Private
# 11      51 to 200 Employees    2016               Company - Private
# 12   1001 to 5000 Employees    1946               Company - Private
# 13  5001 to 10000 Employees    1912                Company - Public
# 14   1001 to 5000 Employees      --               Company - Private
# 15         10000+ Employees    1972                Company - Public
# 16      51 to 200 Employees      --               Company - Private
# 17        1 to 50 Employees      --                Company - Public
# 18         10000+ Employees    1975                Company - Public
# 19                  Unknown      --               Company - Private
# 20                       -1      -1                              -1
# 21     201 to 500 Employees    2002               Company - Private
# 22                  Unknown      --                Company - Public
# 23    501 to 1000 Employees      --                   Self-employed
# 24         10000+ Employees    1994               Company - Private
# 25        1 to 50 Employees      --               Company - Private
# 26      51 to 200 Employees      --               Company - Private
# 27    501 to 1000 Employees    2001                Company - Public
# 28                  Unknown      --               Company - Private
# 29    501 to 1000 Employees    1894          Nonprofit Organization
# 30        1 to 50 Employees    2014               Company - Private
# 31         10000+ Employees    2004               Company - Private
# 32                       -1      -1                              -1
# 33         10000+ Employees    1978                Company - Public
# 34   1001 to 5000 Employees    2011                Company - Public
#
#                                    Industry                            Sector  \
# 0                   Internet & Web Services            Information Technology
# 1   Information Technology Support Services            Information Technology
# 2                                        --                                --
# 3                   Colleges & Universities                         Education
# 4   Information Technology Support Services            Information Technology
# 5   Information Technology Support Services            Information Technology
# 6   Enterprise Software & Network Solutions            Information Technology
# 7         General Merchandise & Superstores                Retail & Wholesale
# 8                                        --                                --
# 9                    Research & Development           Management & Consulting
# 10                      Aerospace & Defense               Aerospace & Defense
# 11                            HR Consulting        Human Resources & Staffing
# 12                  Machinery Manufacturing                     Manufacturing
# 13                        Banking & Lending                Financial Services
# 14                      Business Consulting           Management & Consulting
# 15  Enterprise Software & Network Solutions            Information Technology
# 16            Education & Training Services                         Education
# 17                                       --                                --
# 18            Computer Hardware Development            Information Technology
# 19                                       --                                --
# 20                                       -1                                -1
# 21  Information Technology Support Services            Information Technology
# 22                     Software Development            Information Technology
# 23                  Civic & Social Services                   Nonprofit & NGO
# 24              Telecommunications Services                Telecommunications
# 25                      Business Consulting           Management & Consulting
# 26                                       --                                --
# 27         Health Care Services & Hospitals                        Healthcare
# 28                       Insurance Carriers                         Insurance
# 29                      Sports & Recreation  Arts, Entertainment & Recreation
# 30  Enterprise Software & Network Solutions            Information Technology
# 31                  Internet & Web Services            Information Technology
# 32                                       -1                                -1
# 33       Home Furniture & Housewares Stores                Retail & Wholesale
# 34         Health Care Services & Hospitals                        Healthcare
#
#                              Revenue  \
# 0           Unknown / Non-Applicable
# 1            $5 to $25 million (USD)
# 2           Unknown / Non-Applicable
# 3           Unknown / Non-Applicable
# 4            $5 to $25 million (USD)
# 5           Unknown / Non-Applicable
# 6           Unknown / Non-Applicable
# 7           Unknown / Non-Applicable
# 8           Unknown / Non-Applicable
# 9           Unknown / Non-Applicable
# 10        $100 to $500 million (USD)
# 11           $5 to $25 million (USD)
# 12  $500 million to $1 billion (USD)
# 13          Unknown / Non-Applicable
# 14          Unknown / Non-Applicable
# 15                $10+ billion (USD)
# 16           $5 to $25 million (USD)
# 17          Unknown / Non-Applicable
# 18                $10+ billion (USD)
# 19          Unknown / Non-Applicable
# 20                                -1
# 21          Unknown / Non-Applicable
# 22          Unknown / Non-Applicable
# 23         $25 to $100 million (USD)
# 24            $1 to $5 billion (USD)
# 25           $5 to $25 million (USD)
# 26          Unknown / Non-Applicable
# 27         $25 to $100 million (USD)
# 28          Unknown / Non-Applicable
# 29        $100 to $500 million (USD)
# 30          Unknown / Non-Applicable
# 31            $1 to $5 billion (USD)
# 32                                -1
# 33                $10+ billion (USD)
# 34         $25 to $100 million (USD)
#
#                                                   URL
# 0   https://www.glassdoor.com/job-listing/data-ana...
# 1   https://www.glassdoor.com/job-listing/data-ana...
# 2   https://www.glassdoor.com/job-listing/data-sci...
# 3   https://www.glassdoor.com/job-listing/research...
# 4   https://www.glassdoor.com/job-listing/data-sci...
# 5   https://www.glassdoor.com/job-listing/data-sci...
# 6   https://www.glassdoor.com/job-listing/data-eng...
# 7   https://www.glassdoor.com/job-listing/data-eng...
# 8   https://www.glassdoor.com/job-listing/data-sci...
# 9   https://www.glassdoor.com/job-listing/data-eng...
# 10  https://www.glassdoor.com/job-listing/data-sci...
# 11  https://www.glassdoor.com/job-listing/data-sci...
# 12  https://www.glassdoor.com/job-listing/data-sci...
# 13  https://www.glassdoor.com/job-listing/associat...
# 14  https://www.glassdoor.com/job-listing/product-...
# 15  https://www.glassdoor.com/job-listing/data-sci...
# 16  https://www.glassdoor.com/job-listing/data-ana...
# 17  https://www.glassdoor.com/job-listing/data-ana...
# 18  https://www.glassdoor.com/job-listing/data-sci...
# 19  https://www.glassdoor.com/job-listing/data-ana...
# 20  https://www.glassdoor.com/job-listing/data-sci...
# 21  https://www.glassdoor.com/job-listing/data-eng...
# 22  https://www.glassdoor.com/job-listing/data-eng...
# 23  https://www.glassdoor.com/job-listing/data-sci...
# 24  https://www.glassdoor.com/job-listing/engineer...
# 25  https://www.glassdoor.com/job-listing/data-ana...
# 26  https://www.glassdoor.com/job-listing/data-sci...
# 27  https://www.glassdoor.com/job-listing/data-ana...
# 28  https://www.glassdoor.com/job-listing/data-eng...
# 29  https://www.glassdoor.com/job-listing/associat...
# 30  https://www.glassdoor.com/job-listing/machine-...
# 31  https://www.glassdoor.com/job-listing/associat...
# 32  https://www.glassdoor.com/job-listing/data-ana...
# 33  https://www.glassdoor.com/job-listing/data-sci...
# 34  https://www.glassdoor.com/job-listing/data-sci...

# %%
df.to_csv('Data Science Jobs updated.csv')
# Out:
#                                            Job Title  \
# 0                                     Data Analytics
# 1  DATA SCIENCE: SAP Next Talent - Rotational Pro...
# 2                                      Data Engineer
# 3                     Data Scientist (Hourly Remote)
# 4                                     Data Scientist
# 5                              Manager, Data Science
# 6                               Data Science Manager
# 7                                       Data Science
# 8                                     Data Scientist
#
#                             Salary Estimate  \
# 0  $38.00 - $45.00 Per Hour (Employer est.)
# 1
# 2             $105K - $160K (Employer est.)
# 3  $45.00 - $80.00 Per Hour (Employer est.)
# 4             $120K - $130K (Employer est.)
# 5             $154K - $220K (Employer est.)
# 6             $96K - $156K (Glassdoor est.)
# 7             $117K - $229K (Employer est.)
# 8             $92K - $151K (Glassdoor est.)
#
#                                      Job Description Rating  \
# 0  Minimum three years experience in data science...    3.9
# 1                                                       4.2
# 2  Communicates technical concepts to non-technic...    3.9
# 3  They will be encouraged to propose innovative ...    4.1
# 4  Data science: 1 year (Preferred). Expertise in...    4.0
# 5  The engineering organization at ServiceTitan i...    3.4
# 6  Encourages innovation within the team to explo...    4.0
# 7  Doctorate in Data Science, Mathematics, Statis...    4.2
# 8  Experience with data engineering and data scie...    4.0
#
#                  Company Name       Location                     Size Founded  \
# 0            J & S Consulting     Tucker, GA      51 to 200 Employees      --
# 1                         SAP                        10000+ Employees    1972
# 2            Costco Wholesale     Dallas, TX         10000+ Employees    1976
# 3            ARES Corporation  United States    501 to 1000 Employees    1992
# 4        element technologies         Remote      51 to 200 Employees    2000
# 5                ServiceTitan         Remote   1001 to 5000 Employees    2013
# 6  Boston Children's Hospital     Boston, MA  5001 to 10000 Employees    1869
# 7                   Microsoft    Redmond, WA         10000+ Employees    1975
# 8                       RADAR   San Jose, CA    501 to 1000 Employees      --
#
#         Type of ownership                                 Industry  \
# 0       Company - Private  Information Technology Support Services
# 1        Company - Public  Enterprise Software & Network Solutions
# 2        Company - Public        General Merchandise & Superstores
# 3       Company - Private                      Aerospace & Defense
# 4       Company - Private  Information Technology Support Services
# 5       Company - Private                     Software Development
# 6  Nonprofit Organization         Health Care Services & Hospitals
# 7        Company - Public            Computer Hardware Development
# 8           Self-employed                  Civic & Social Services
#
#                    Sector                     Revenue
# 0  Information Technology     $5 to $25 million (USD)
# 1  Information Technology          $10+ billion (USD)
# 2      Retail & Wholesale    Unknown / Non-Applicable
# 3     Aerospace & Defense  $100 to $500 million (USD)
# 4  Information Technology    Unknown / Non-Applicable
# 5  Information Technology    Unknown / Non-Applicable
# 6              Healthcare    Unknown / Non-Applicable
# 7  Information Technology          $10+ billion (USD)
# 8         Nonprofit & NGO   $25 to $100 million (USD)
